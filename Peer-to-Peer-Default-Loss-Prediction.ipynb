# %% [markdown]
# ## Peer2Peer Loss Given Default Prediction
#
#
#
# This solution predicts the Loss due to default of the borrowers who are most likely to default on their Consumer loans in Peer-to-Peer lending. During the training stage, the solution understands the dataset, handles missing data and class imbalance, conducts feature interaction on the training data and selects a subset of best features based on feature importance. It then trains on multiple ML models, identifies the best performing model and tunes it accordingly. This trained model is then selected for prediction on the test data.
#
#
#
# This sample notebook shows you how to deploy Peer2Peer Loss Given Default Prediction using Amazon SageMaker.
#
# > **Note**: This is a reference notebook and it cannot run unless you make changes suggested in the notebook.
#
# #### Pre-requisites:
# 1. **Note**: This notebook contains elements which render correctly in Jupyter interface. Open this notebook from an Amazon SageMaker Notebook Instance or Amazon SageMaker Studio.
# 1. Ensure that IAM role used has **AmazonSageMakerFullAccess**
# 1. To deploy this ML model successfully, ensure that:
#     1. Either your IAM role has these three permissions and you have authority to make AWS Marketplace subscriptions in the AWS account used:
#         1. **aws-marketplace:ViewSubscriptions**
#         1. **aws-marketplace:Unsubscribe**
#         1. **aws-marketplace:Subscribe**
#     2. or your AWS account has a subscription to Peer-to-Peer Default Loss Prediction. If so, skip step: [Subscribe to the model package](#1.-Subscribe-to-the-model-package)
#     3. Make sure to install below mentioned python libraries before running this notebook
#
# #### Contents:
# 1. [Subscribe to the model package](#1.-Subscribe-to-the-model-package)
# 2. [Usage Instruction](#2.-Usage-Instruction)
# 3. [Training](#3.-Training)
# 4. [Sample Data](#4.-Sample-Data)
# 5. [Perform batch inference](#5.-Perform-batch-inference)
# 6. [Create an endpoint and perform real-time inference](#6.-Create-an-endpoint-and-perform-real-time-inference)
# 7. [Clean-up](#7.-Clean-up)
#
#
# #### Usage instructions
# You can run this notebook one cell at a time (By using Shift+Enter for running a cell).

# %% [markdown]
# ### 1. Subscribe to the model package

# %% [markdown]
# To subscribe to the model package:
# 1. Open the algorithm listing page **Peer2Peer Loss Given Default Prediction**
# 1. On the AWS Marketplace listing, click on the **Continue to subscribe** button.
# 1. On the **Subscribe to this software** page, review and click on **"Accept Offer"** if you and your organization agrees with EULA, pricing, and support terms.
# 1. Once you click on **Continue to configuration button** and then choose a **region**, you will see a **Product Arn** displayed. This is the model package ARN that you need to specify while creating a deployable model using Boto3. Copy the ARN corresponding to your region and specify the same in the following cell.

# %% [markdown]
# ### 2. Usage Instruction

# %% [markdown]
# The deployed solution has these 2 steps:
# 1: The solution trains on user provided historical training data and builds & saves a ML model which is a representation of the historical data.
# 2: Once the model is generated, the solution can be used to predict on any new data as input file.
# To achieve this end, the solution deploys the following 2 APIs over AWS Sagemaker:
#
# 1.Training API: The system trains on user provided historical data with relevant features and builds & saves a ML model.
# 2.Testing API: Once the model is generated, the solution can be used to predict the loss given default for a given test data.
#
#
# ## Input
# Supported content types: `text/csv`
# * Following is the mandatory inputs for the APIs:
#  * The Target variable should be named**LossGivenDefault**, this features tells us the Percentage of amount lost when Borrower Defaults.
#
#
# Note:
# 1.	Two separate csv input files are required for training and testing.
#   * Name of the training file should be train.csv
#   * Name of the testing file should be sample_input.csv
#
# ## Output
# • Content type: ` text/csv`
# * Solution will generate an output csv file which will contain an additional columns as the prediction along with the columns in the new data.
# *  The additional columns will be **Label**.
#
# ## Invoking endpoint
#
# ### AWS CLI Command
# If you are using real time inferencing, please create the endpoint first and then use the  following command to invoke it:
#
# ``` bash
# !aws sagemaker-runtime invoke-endpoint --endpoint-name $model_name --body fileb://$file_name --content-type 'text/csv' --region us-east-2 sample_output.csv
# ```
# Substitute the following parameters:
# * `"model-name"` - name of the inference endpoint where the model is deployed
# * `file_name` - input csv file name
# * `text/csv` - content type of the given input
# * `sample_output.csv` - filename where the inference results are written to.

# %%
import base64 
import uuid
from sagemaker import ModelPackage
import sagemaker as sage
from sagemaker import get_execution_role
from sagemaker import ModelPackage
import boto3
from IPython.display import Image
from PIL import Image
import numpy as np
import pandas as pd
import cv2
from numpy import asarray

# %%
role = get_execution_role()

sagemaker_session = sage.Session()

bucket=sagemaker_session.default_bucket()
bucket
# Out:
# 'sagemaker-us-east-2-786796469737'

# %%
# S3 prefixes
common_prefix = "Peer_to_Peer_Default_Loss_Prediction"
training_input_prefix = common_prefix + "/training-input-data"
batch_inference_input_prefix = common_prefix + "/batch-inference-input-data"

# %%
sagemaker_session = sage.Session()

# %%
# Maintaine this directory structure
TRAINING_WORKDIR = "data/training"

TRAINING_DATA = TRAINING_WORKDIR + "/train.csv"

# %%
TRAINING_WORKDIR = "data/training"

training_input = sagemaker_session.upload_data(TRAINING_WORKDIR, key_prefix=training_input_prefix)
print ("Training Data Location " + training_input)
# Out:
# Training Data Location s3://sagemaker-us-east-2-786796469737/Peer_to_Peer_Default_Loss_Prediction/training-input-data

# %% [markdown]
# ### 3. Training

# %%
import json
import time
from sagemaker.algorithm import AlgorithmEstimator

# %% [markdown]
# ##### Algorithm ARN

# %%
algorithm_arn ='' # put your ARN here

# %%
algo = AlgorithmEstimator(
    algorithm_arn=algorithm_arn,
    role=role,
    instance_count=1,
    instance_type='ml.m5.12xlarge',
    base_job_name='Peer-to-Peer-Default-Loss-Prediction')

# %%
print ("Now run the training job using algorithm arn %s in region %s" % (algorithm_arn, sagemaker_session.boto_region_name))
algo.fit({'training': training_input})
# Out:
# Now run the training job using algorithm arn arn:aws:sagemaker:us-east-2:786796469737:algorithm/default-loss-prediction-v3 in region us-east-2
# 2021-07-30 11:06:58 Starting - Starting the training job...
# 2021-07-30 11:07:21 Starting - Launching requested ML instancesProfilerReport-1627643218: InProgress
# ...
# 2021-07-30 11:07:48 Starting - Preparing the instances for training......
# 2021-07-30 11:08:59 Downloading - Downloading input data...
# 2021-07-30 11:09:22 Training - Downloading the training image...
# 2021-07-30 11:09:52 Training - Training image download completed. Training in progress..RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# Starting the training.
# (68916, 12)
# ['WorkExperience'] ['Age', 'LoanDuration', 'MonthlyPayment', 'Amount', 'Gender', 'IncomeTotal', 'UseOfLoan', 'Education', 'HomeOwnershipType', 'OccupationArea']
# IntProgress(value=0, description='Processing: ', max=3)
#
#
# Initiated  . . . . . . . . . . . . . . . . . .              11:09:56
# Status     . . . . . . . . . . . . . . . . . .  Loading Dependencies
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                     11:09:56
# Status     . . . . . . . . . . . . . . . . . .  Preparing Data for Modeling
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                     11:09:56
# Status     . . . . . . . . . . . . . . . . . .  Preparing Data for Modeling
#
#
# Initiated  . . . . . . . . . . . . . . . . . .            11:09:56
# Status     . . . . . . . . . . . . . . . . . .  Preprocessing Data
#
#
# Initiated  . . . . . . . . . . . . . . . . . .            11:09:56
# Status     . . . . . . . . . . . . . . . . . .  Preprocessing Data
# Setup Succesfully Completed!
# #033[2K#015#033[2K#015<pandas.io.formats.style.Styler object at 0x7f8dc92ace80>
# IntProgress(value=0, description='Processing: ', max=89)
#
#
# Initiated  . . . . . . . . . . . . . . . . . .              11:10:01
# Status     . . . . . . . . . . . . . . . . . .  Loading Dependencies
# Estimator  . . . . . . . . . . . . . . . . . .     Compiling Library
# Empty DataFrame
# Columns: [Model, MAE, MSE, RMSE, R2, RMSLE, MAPE, TT (Sec)]
# Index: []
#
#
# Initiated  . . . . . . . . . . . . . . . . . .           11:10:01
# Status     . . . . . . . . . . . . . . . . . .  Loading Estimator
# Estimator  . . . . . . . . . . . . . . . . . .  Compiling Library
#
#
# Initiated  . . . . . . . . . . . . . . . . . .           11:10:01
# Status     . . . . . . . . . . . . . . . . . .  Loading Estimator
# Estimator  . . . . . . . . . . . . . . . . . .  Compiling Library
#
#
# Initiated  . . . . . . . . . . . . . . . . . .           11:10:01
# Status     . . . . . . . . . . . . . . . . . .  Loading Estimator
# Estimator  . . . . . . . . . . . . . . . . . .  Linear Regression
#
#
# Initiated  . . . . . . . . . . . . . . . . . .           11:10:01
# Status     . . . . . . . . . . . . . . . . . .  Loading Estimator
# Estimator  . . . . . . . . . . . . . . . . . .  Linear Regression
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             11:10:01
# Status     . . . . . . . . . . . . . . . . . .  Selecting Estimator
# Estimator  . . . . . . . . . . . . . . . . . .    Linear Regression
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             11:10:01
# Status     . . . . . . . . . . . . . . . . . .  Selecting Estimator
# Estimator  . . . . . . . . . . . . . . . . . .    Linear Regression
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             11:10:01
# Status     . . . . . . . . . . . . . . . . . .  Selecting Estimator
# Estimator  . . . . . . . . . . . . . . . . . .    Linear Regression
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             11:10:01
# Status     . . . . . . . . . . . . . . . . . .  Selecting Estimator
# Estimator  . . . . . . . . . . . . . . . . . .    Linear Regression
#
#
# Initiated  . . . . . . . . . . . . . . . . . .           11:10:01
# Status     . . . . . . . . . . . . . . . . . .    Initializing CV
# Estimator  . . . . . . . . . . . . . . . . . .  Linear Regression
#
#
# Initiated  . . . . . . . . . . . . . . . . . .           11:10:01
# Status     . . . . . . . . . . . . . . . . . .    Initializing CV
# Estimator  . . . . . . . . . . . . . . . . . .  Linear Regression
#
#
# Initiated  . . . . . . . . . . . . . . . . . .           11:10:01
# Status     . . . . . . . . . . . . . . . . . .    Fitting 3 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  Linear Regression
#
#
# Initiated  . . . . . . . . . . . . . . . . . .           11:10:01
# Status     . . . . . . . . . . . . . . . . . .    Fitting 3 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  Linear Regression
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# <pandas.io.formats.style.Styler object at 0x7f8dc909f6d0>
#
#
# Initiated  . . . . . . . . . . . . . . . . . .          11:10:01
# Status     . . . . . . . . . . . . . . . . . .   Fitting 3 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  Lasso Regression
#
#
# Initiated  . . . . . . . . . . . . . . . . . .          11:10:01
# Status     . . . . . . . . . . . . . . . . . .   Fitting 3 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  Lasso Regression
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             11:10:01
# Status     . . . . . . . . . . . . . . . . . .  Selecting Estimator
# Estimator  . . . . . . . . . . . . . . . . . .     Lasso Regression
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             11:10:01
# Status     . . . . . . . . . . . . . . . . . .  Selecting Estimator
# Estimator  . . . . . . . . . . . . . . . . . .     Lasso Regression
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             11:10:01
# Status     . . . . . . . . . . . . . . . . . .  Selecting Estimator
# Estimator  . . . . . . . . . . . . . . . . . .     Lasso Regression
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             11:10:01
# Status     . . . . . . . . . . . . . . . . . .  Selecting Estimator
# Estimator  . . . . . . . . . . . . . . . . . .     Lasso Regression
#
#
# Initiated  . . . . . . . . . . . . . . . . . .          11:10:01
# Status     . . . . . . . . . . . . . . . . . .   Initializing CV
# Estimator  . . . . . . . . . . . . . . . . . .  Lasso Regression
#
#
# Initiated  . . . . . . . . . . . . . . . . . .          11:10:01
# Status     . . . . . . . . . . . . . . . . . .   Initializing CV
# Estimator  . . . . . . . . . . . . . . . . . .  Lasso Regression
#
#
# Initiated  . . . . . . . . . . . . . . . . . .          11:10:01
# Status     . . . . . . . . . . . . . . . . . .   Fitting 3 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  Lasso Regression
#
#
# Initiated  . . . . . . . . . . . . . . . . . .          11:10:01
# Status     . . . . . . . . . . . . . . . . . .   Fitting 3 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  Lasso Regression
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# <pandas.io.formats.style.Styler object at 0x7f8dc94d4bb0>
#
#
# Initiated  . . . . . . . . . . . . . . . . . .          11:10:01
# Status     . . . . . . . . . . . . . . . . . .   Fitting 3 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  Ridge Regression
#
#
# Initiated  . . . . . . . . . . . . . . . . . .          11:10:01
# Status     . . . . . . . . . . . . . . . . . .   Fitting 3 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  Ridge Regression
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             11:10:01
# Status     . . . . . . . . . . . . . . . . . .  Selecting Estimator
# Estimator  . . . . . . . . . . . . . . . . . .     Ridge Regression
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             11:10:01
# Status     . . . . . . . . . . . . . . . . . .  Selecting Estimator
# Estimator  . . . . . . . . . . . . . . . . . .     Ridge Regression
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             11:10:01
# Status     . . . . . . . . . . . . . . . . . .  Selecting Estimator
# Estimator  . . . . . . . . . . . . . . . . . .     Ridge Regression
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             11:10:01
# Status     . . . . . . . . . . . . . . . . . .  Selecting Estimator
# Estimator  . . . . . . . . . . . . . . . . . .     Ridge Regression
#
#
# Initiated  . . . . . . . . . . . . . . . . . .          11:10:01
# Status     . . . . . . . . . . . . . . . . . .   Initializing CV
# Estimator  . . . . . . . . . . . . . . . . . .  Ridge Regression
#
#
# Initiated  . . . . . . . . . . . . . . . . . .          11:10:01
# Status     . . . . . . . . . . . . . . . . . .   Initializing CV
# Estimator  . . . . . . . . . . . . . . . . . .  Ridge Regression
#
#
# Initiated  . . . . . . . . . . . . . . . . . .          11:10:01
# Status     . . . . . . . . . . . . . . . . . .   Fitting 3 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  Ridge Regression
#
#
# Initiated  . . . . . . . . . . . . . . . . . .          11:10:01
# Status     . . . . . . . . . . . . . . . . . .   Fitting 3 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  Ridge Regression
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=1.02807e-17): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=1.41337e-17): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=9.92105e-18): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# <pandas.io.formats.style.Styler object at 0x7f8dc8f33400>
#
#
# Initiated  . . . . . . . . . . . . . . . . . .         11:10:01
# Status     . . . . . . . . . . . . . . . . . .  Fitting 3 Folds
# Estimator  . . . . . . . . . . . . . . . . . .      Elastic Net
#
#
# Initiated  . . . . . . . . . . . . . . . . . .         11:10:01
# Status     . . . . . . . . . . . . . . . . . .  Fitting 3 Folds
# Estimator  . . . . . . . . . . . . . . . . . .      Elastic Net
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             11:10:01
# Status     . . . . . . . . . . . . . . . . . .  Selecting Estimator
# Estimator  . . . . . . . . . . . . . . . . . .          Elastic Net
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             11:10:01
# Status     . . . . . . . . . . . . . . . . . .  Selecting Estimator
# Estimator  . . . . . . . . . . . . . . . . . .          Elastic Net
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             11:10:01
# Status     . . . . . . . . . . . . . . . . . .  Selecting Estimator
# Estimator  . . . . . . . . . . . . . . . . . .          Elastic Net
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             11:10:01
# Status     . . . . . . . . . . . . . . . . . .  Selecting Estimator
# Estimator  . . . . . . . . . . . . . . . . . .          Elastic Net
#
#
# Initiated  . . . . . . . . . . . . . . . . . .         11:10:01
# Status     . . . . . . . . . . . . . . . . . .  Initializing CV
# Estimator  . . . . . . . . . . . . . . . . . .      Elastic Net
#
#
# Initiated  . . . . . . . . . . . . . . . . . .         11:10:01
# Status     . . . . . . . . . . . . . . . . . .  Initializing CV
# Estimator  . . . . . . . . . . . . . . . . . .      Elastic Net
#
#
# Initiated  . . . . . . . . . . . . . . . . . .         11:10:01
# Status     . . . . . . . . . . . . . . . . . .  Fitting 3 Folds
# Estimator  . . . . . . . . . . . . . . . . . .      Elastic Net
#
#
# Initiated  . . . . . . . . . . . . . . . . . .         11:10:01
# Status     . . . . . . . . . . . . . . . . . .  Fitting 3 Folds
# Estimator  . . . . . . . . . . . . . . . . . .      Elastic Net
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# <pandas.io.formats.style.Styler object at 0x7f8dc8f33e20>
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                11:10:01
# Status     . . . . . . . . . . . . . . . . . .         Fitting 3 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  Least Angle Regression
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                11:10:01
# Status     . . . . . . . . . . . . . . . . . .         Fitting 3 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  Least Angle Regression
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                11:10:01
# Status     . . . . . . . . . . . . . . . . . .     Selecting Estimator
# Estimator  . . . . . . . . . . . . . . . . . .  Least Angle Regression
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                11:10:01
# Status     . . . . . . . . . . . . . . . . . .     Selecting Estimator
# Estimator  . . . . . . . . . . . . . . . . . .  Least Angle Regression
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                11:10:01
# Status     . . . . . . . . . . . . . . . . . .     Selecting Estimator
# Estimator  . . . . . . . . . . . . . . . . . .  Least Angle Regression
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                11:10:01
# Status     . . . . . . . . . . . . . . . . . .     Selecting Estimator
# Estimator  . . . . . . . . . . . . . . . . . .  Least Angle Regression
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                11:10:01
# Status     . . . . . . . . . . . . . . . . . .         Initializing CV
# Estimator  . . . . . . . . . . . . . . . . . .  Least Angle Regression
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                11:10:01
# Status     . . . . . . . . . . . . . . . . . .         Initializing CV
# Estimator  . . . . . . . . . . . . . . . . . .  Least Angle Regression
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                11:10:01
# Status     . . . . . . . . . . . . . . . . . .         Fitting 3 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  Least Angle Regression
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                11:10:01
# Status     . . . . . . . . . . . . . . . . . .         Fitting 3 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  Least Angle Regression
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_least_angle.py:571: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 16 iterations, i.e. alpha=3.694e-05, with an active set of 15 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn('Regressors in active set degenerate. '
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_least_angle.py:571: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 28 iterations, i.e. alpha=6.518e-06, with an active set of 28 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn('Regressors in active set degenerate. '
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_least_angle.py:571: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 20 iterations, i.e. alpha=3.228e-05, with an active set of 18 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn('Regressors in active set degenerate. '
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_least_angle.py:571: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 41 iterations, i.e. alpha=1.731e-06, with an active set of 40 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn('Regressors in active set degenerate. '
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_least_angle.py:571: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 34 iterations, i.e. alpha=2.072e-05, with an active set of 31 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn('Regressors in active set degenerate. '
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_least_angle.py:571: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 35 iterations, i.e. alpha=1.687e-05, with an active set of 32 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn('Regressors in active set degenerate. '
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_least_angle.py:571: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 35 iterations, i.e. alpha=1.590e-05, with an active set of 32 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn('Regressors in active set degenerate. '
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_least_angle.py:571: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 36 iterations, i.e. alpha=1.198e-05, with an active set of 33 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn('Regressors in active set degenerate. '
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_least_angle.py:571: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 36 iterations, i.e. alpha=1.070e-05, with an active set of 33 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn('Regressors in active set degenerate. '
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_least_angle.py:571: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 41 iterations, i.e. alpha=7.903e-06, with an active set of 37 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn('Regressors in active set degenerate. '
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_least_angle.py:571: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 42 iterations, i.e. alpha=6.272e-06, with an active set of 38 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn('Regressors in active set degenerate. '
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_least_angle.py:571: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 44 iterations, i.e. alpha=3.435e-06, with an active set of 40 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn('Regressors in active set degenerate. '
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_least_angle.py:571: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 46 iterations, i.e. alpha=1.629e-06, with an active set of 42 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn('Regressors in active set degenerate. '
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_least_angle.py:571: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 46 iterations, i.e. alpha=1.361e-06, with an active set of 42 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn('Regressors in active set degenerate. '
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_least_angle.py:571: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 46 iterations, i.e. alpha=1.124e-06, with an active set of 42 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn('Regressors in active set degenerate. '
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_least_angle.py:571: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 46 iterations, i.e. alpha=4.296e-07, with an active set of 42 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn('Regressors in active set degenerate. '
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_least_angle.py:571: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 47 iterations, i.e. alpha=3.289e-07, with an active set of 43 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn('Regressors in active set degenerate. '
# <pandas.io.formats.style.Styler object at 0x7f8dc94994f0>
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                      11:10:01
# Status     . . . . . . . . . . . . . . . . . .               Fitting 3 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  Lasso Least Angle Regression
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                      11:10:01
# Status     . . . . . . . . . . . . . . . . . .               Fitting 3 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  Lasso Least Angle Regression
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                      11:10:01
# Status     . . . . . . . . . . . . . . . . . .           Selecting Estimator
# Estimator  . . . . . . . . . . . . . . . . . .  Lasso Least Angle Regression
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                      11:10:01
# Status     . . . . . . . . . . . . . . . . . .           Selecting Estimator
# Estimator  . . . . . . . . . . . . . . . . . .  Lasso Least Angle Regression
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                      11:10:01
# Status     . . . . . . . . . . . . . . . . . .           Selecting Estimator
# Estimator  . . . . . . . . . . . . . . . . . .  Lasso Least Angle Regression
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                      11:10:01
# Status     . . . . . . . . . . . . . . . . . .           Selecting Estimator
# Estimator  . . . . . . . . . . . . . . . . . .  Lasso Least Angle Regression
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                      11:10:01
# Status     . . . . . . . . . . . . . . . . . .               Initializing CV
# Estimator  . . . . . . . . . . . . . . . . . .  Lasso Least Angle Regression
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                      11:10:01
# Status     . . . . . . . . . . . . . . . . . .               Initializing CV
# Estimator  . . . . . . . . . . . . . . . . . .  Lasso Least Angle Regression
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                      11:10:01
# Status     . . . . . . . . . . . . . . . . . .               Fitting 3 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  Lasso Least Angle Regression
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                      11:10:01
# Status     . . . . . . . . . . . . . . . . . .               Fitting 3 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  Lasso Least Angle Regression
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# <pandas.io.formats.style.Styler object at 0x7f8dc94d4bb0>
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                     11:10:01
# Status     . . . . . . . . . . . . . . . . . .              Fitting 3 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  Orthogonal Matching Pursuit
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                     11:10:01
# Status     . . . . . . . . . . . . . . . . . .              Fitting 3 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  Orthogonal Matching Pursuit
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                     11:10:01
# Status     . . . . . . . . . . . . . . . . . .          Selecting Estimator
# Estimator  . . . . . . . . . . . . . . . . . .  Orthogonal Matching Pursuit
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                     11:10:01
# Status     . . . . . . . . . . . . . . . . . .          Selecting Estimator
# Estimator  . . . . . . . . . . . . . . . . . .  Orthogonal Matching Pursuit
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                     11:10:01
# Status     . . . . . . . . . . . . . . . . . .          Selecting Estimator
# Estimator  . . . . . . . . . . . . . . . . . .  Orthogonal Matching Pursuit
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                     11:10:01
# Status     . . . . . . . . . . . . . . . . . .          Selecting Estimator
# Estimator  . . . . . . . . . . . . . . . . . .  Orthogonal Matching Pursuit
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                     11:10:01
# Status     . . . . . . . . . . . . . . . . . .              Initializing CV
# Estimator  . . . . . . . . . . . . . . . . . .  Orthogonal Matching Pursuit
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                     11:10:01
# Status     . . . . . . . . . . . . . . . . . .              Initializing CV
# Estimator  . . . . . . . . . . . . . . . . . .  Orthogonal Matching Pursuit
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                     11:10:01
# Status     . . . . . . . . . . . . . . . . . .              Fitting 3 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  Orthogonal Matching Pursuit
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                     11:10:01
# Status     . . . . . . . . . . . . . . . . . .              Fitting 3 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  Orthogonal Matching Pursuit
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# <pandas.io.formats.style.Styler object at 0x7f8dc92e6970>
#
#
# Initiated  . . . . . . . . . . . . . . . . . .         11:10:01
# Status     . . . . . . . . . . . . . . . . . .  Fitting 3 Folds
# Estimator  . . . . . . . . . . . . . . . . . .   Bayesian Ridge
#
#
# Initiated  . . . . . . . . . . . . . . . . . .         11:10:01
# Status     . . . . . . . . . . . . . . . . . .  Fitting 3 Folds
# Estimator  . . . . . . . . . . . . . . . . . .   Bayesian Ridge
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             11:10:01
# Status     . . . . . . . . . . . . . . . . . .  Selecting Estimator
# Estimator  . . . . . . . . . . . . . . . . . .       Bayesian Ridge
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             11:10:01
# Status     . . . . . . . . . . . . . . . . . .  Selecting Estimator
# Estimator  . . . . . . . . . . . . . . . . . .       Bayesian Ridge
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             11:10:01
# Status     . . . . . . . . . . . . . . . . . .  Selecting Estimator
# Estimator  . . . . . . . . . . . . . . . . . .       Bayesian Ridge
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             11:10:01
# Status     . . . . . . . . . . . . . . . . . .  Selecting Estimator
# Estimator  . . . . . . . . . . . . . . . . . .       Bayesian Ridge
#
#
# Initiated  . . . . . . . . . . . . . . . . . .         11:10:01
# Status     . . . . . . . . . . . . . . . . . .  Initializing CV
# Estimator  . . . . . . . . . . . . . . . . . .   Bayesian Ridge
#
#
# Initiated  . . . . . . . . . . . . . . . . . .         11:10:01
# Status     . . . . . . . . . . . . . . . . . .  Initializing CV
# Estimator  . . . . . . . . . . . . . . . . . .   Bayesian Ridge
#
#
# Initiated  . . . . . . . . . . . . . . . . . .         11:10:01
# Status     . . . . . . . . . . . . . . . . . .  Fitting 3 Folds
# Estimator  . . . . . . . . . . . . . . . . . .   Bayesian Ridge
#
#
# Initiated  . . . . . . . . . . . . . . . . . .         11:10:01
# Status     . . . . . . . . . . . . . . . . . .  Fitting 3 Folds
# Estimator  . . . . . . . . . . . . . . . . . .   Bayesian Ridge
# RuntimeErrorRuntimeError: : module compiled against API version 0xe but this version of numpy is 0xdmodule compiled against API version 0xe but this version of numpy is 0xd
#
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# <pandas.io.formats.style.Styler object at 0x7f8dc909a190>
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                      11:10:01
# Status     . . . . . . . . . . . . . . . . . .               Fitting 3 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  Passive Aggressive Regressor
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                      11:10:01
# Status     . . . . . . . . . . . . . . . . . .               Fitting 3 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  Passive Aggressive Regressor
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                      11:10:01
# Status     . . . . . . . . . . . . . . . . . .           Selecting Estimator
# Estimator  . . . . . . . . . . . . . . . . . .  Passive Aggressive Regressor
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                      11:10:01
# Status     . . . . . . . . . . . . . . . . . .           Selecting Estimator
# Estimator  . . . . . . . . . . . . . . . . . .  Passive Aggressive Regressor
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                      11:10:01
# Status     . . . . . . . . . . . . . . . . . .           Selecting Estimator
# Estimator  . . . . . . . . . . . . . . . . . .  Passive Aggressive Regressor
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                      11:10:01
# Status     . . . . . . . . . . . . . . . . . .           Selecting Estimator
# Estimator  . . . . . . . . . . . . . . . . . .  Passive Aggressive Regressor
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                      11:10:01
# Status     . . . . . . . . . . . . . . . . . .               Initializing CV
# Estimator  . . . . . . . . . . . . . . . . . .  Passive Aggressive Regressor
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                      11:10:01
# Status     . . . . . . . . . . . . . . . . . .               Initializing CV
# Estimator  . . . . . . . . . . . . . . . . . .  Passive Aggressive Regressor
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                      11:10:01
# Status     . . . . . . . . . . . . . . . . . .               Fitting 3 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  Passive Aggressive Regressor
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                      11:10:01
# Status     . . . . . . . . . . . . . . . . . .               Fitting 3 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  Passive Aggressive Regressor
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# /usr/local/lib/python3.8/dist-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.8/dist-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.8/dist-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.8/dist-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.8/dist-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.8/dist-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.8/dist-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.8/dist-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.8/dist-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.8/dist-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.8/dist-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.8/dist-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# ...
# Status     . . . . . . . . . . . . . . . . . .     Fitting 3 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  AdaBoost Regressor
#
#
# Initiated  . . . . . . . . . . . . . . . . . .            11:10:01
# Status     . . . . . . . . . . . . . . . . . .     Fitting 3 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  AdaBoost Regressor
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             11:10:01
# Status     . . . . . . . . . . . . . . . . . .  Selecting Estimator
# Estimator  . . . . . . . . . . . . . . . . . .   AdaBoost Regressor
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             11:10:01
# Status     . . . . . . . . . . . . . . . . . .  Selecting Estimator
# Estimator  . . . . . . . . . . . . . . . . . .   AdaBoost Regressor
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             11:10:01
# Status     . . . . . . . . . . . . . . . . . .  Selecting Estimator
# Estimator  . . . . . . . . . . . . . . . . . .   AdaBoost Regressor
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             11:10:01
# Status     . . . . . . . . . . . . . . . . . .  Selecting Estimator
# Estimator  . . . . . . . . . . . . . . . . . .   AdaBoost Regressor
#
#
# Initiated  . . . . . . . . . . . . . . . . . .            11:10:01
# Status     . . . . . . . . . . . . . . . . . .     Initializing CV
# Estimator  . . . . . . . . . . . . . . . . . .  AdaBoost Regressor
#
#
# Initiated  . . . . . . . . . . . . . . . . . .            11:10:01
# Status     . . . . . . . . . . . . . . . . . .     Initializing CV
# Estimator  . . . . . . . . . . . . . . . . . .  AdaBoost Regressor
#
#
# Initiated  . . . . . . . . . . . . . . . . . .            11:10:01
# Status     . . . . . . . . . . . . . . . . . .     Fitting 3 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  AdaBoost Regressor
#
#
# Initiated  . . . . . . . . . . . . . . . . . .            11:10:01
# Status     . . . . . . . . . . . . . . . . . .     Fitting 3 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  AdaBoost Regressor
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# <pandas.io.formats.style.Styler object at 0x7f8dc92f0b50>
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                     11:10:01
# Status     . . . . . . . . . . . . . . . . . .              Fitting 3 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  Gradient Boosting Regressor
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                     11:10:01
# Status     . . . . . . . . . . . . . . . . . .              Fitting 3 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  Gradient Boosting Regressor
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                     11:10:01
# Status     . . . . . . . . . . . . . . . . . .          Selecting Estimator
# Estimator  . . . . . . . . . . . . . . . . . .  Gradient Boosting Regressor
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                     11:10:01
# Status     . . . . . . . . . . . . . . . . . .          Selecting Estimator
# Estimator  . . . . . . . . . . . . . . . . . .  Gradient Boosting Regressor
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                     11:10:01
# Status     . . . . . . . . . . . . . . . . . .          Selecting Estimator
# Estimator  . . . . . . . . . . . . . . . . . .  Gradient Boosting Regressor
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                     11:10:01
# Status     . . . . . . . . . . . . . . . . . .          Selecting Estimator
# Estimator  . . . . . . . . . . . . . . . . . .  Gradient Boosting Regressor
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                     11:10:01
# Status     . . . . . . . . . . . . . . . . . .              Initializing CV
# Estimator  . . . . . . . . . . . . . . . . . .  Gradient Boosting Regressor
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                     11:10:01
# Status     . . . . . . . . . . . . . . . . . .              Initializing CV
# Estimator  . . . . . . . . . . . . . . . . . .  Gradient Boosting Regressor
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                     11:10:01
# Status     . . . . . . . . . . . . . . . . . .              Fitting 3 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  Gradient Boosting Regressor
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                     11:10:01
# Status     . . . . . . . . . . . . . . . . . .              Fitting 3 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  Gradient Boosting Regressor
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# <pandas.io.formats.style.Styler object at 0x7f8dc909f970>
#                                                 \
#
# Initiated  . . . . . . . . . . . . . . . . . .
# Status     . . . . . . . . . . . . . . . . . .
# Estimator  . . . . . . . . . . . . . . . . . .
#
#
#
# Initiated                         11:10:01
# Status                     Fitting 3 Folds
# Estimator  Light Gradient Boosting Machine
#                                                 \
#
# Initiated  . . . . . . . . . . . . . . . . . .
# Status     . . . . . . . . . . . . . . . . . .
# Estimator  . . . . . . . . . . . . . . . . . .
#
#
#
# Initiated                         11:10:01
# Status                     Fitting 3 Folds
# Estimator  Light Gradient Boosting Machine
#                                                 \
#
# Initiated  . . . . . . . . . . . . . . . . . .
# Status     . . . . . . . . . . . . . . . . . .
# Estimator  . . . . . . . . . . . . . . . . . .
#
#
#
# Initiated                         11:10:01
# Status                 Selecting Estimator
# Estimator  Light Gradient Boosting Machine
#                                                 \
#
# Initiated  . . . . . . . . . . . . . . . . . .
# Status     . . . . . . . . . . . . . . . . . .
# Estimator  . . . . . . . . . . . . . . . . . .
#
#
#
# Initiated                         11:10:01
# Status                 Selecting Estimator
# Estimator  Light Gradient Boosting Machine
#                                                 \
#
# Initiated  . . . . . . . . . . . . . . . . . .
# Status     . . . . . . . . . . . . . . . . . .
# Estimator  . . . . . . . . . . . . . . . . . .
#
#
#
# Initiated                         11:10:01
# Status                 Selecting Estimator
# Estimator  Light Gradient Boosting Machine
#                                                 \
#
# Initiated  . . . . . . . . . . . . . . . . . .
# Status     . . . . . . . . . . . . . . . . . .
# Estimator  . . . . . . . . . . . . . . . . . .
#
#
#
# Initiated                         11:10:01
# Status                 Selecting Estimator
# Estimator  Light Gradient Boosting Machine
#                                                 \
#
# Initiated  . . . . . . . . . . . . . . . . . .
# Status     . . . . . . . . . . . . . . . . . .
# Estimator  . . . . . . . . . . . . . . . . . .
#
#
#
# Initiated                         11:10:01
# Status                     Initializing CV
# Estimator  Light Gradient Boosting Machine
#                                                 \
#
# Initiated  . . . . . . . . . . . . . . . . . .
# Status     . . . . . . . . . . . . . . . . . .
# Estimator  . . . . . . . . . . . . . . . . . .
#
#
#
# Initiated                         11:10:01
# Status                     Initializing CV
# Estimator  Light Gradient Boosting Machine
#                                                 \
#
# Initiated  . . . . . . . . . . . . . . . . . .
# Status     . . . . . . . . . . . . . . . . . .
# Estimator  . . . . . . . . . . . . . . . . . .
#
#
#
# Initiated                         11:10:01
# Status                     Fitting 3 Folds
# Estimator  Light Gradient Boosting Machine
#                                                 \
#
# Initiated  . . . . . . . . . . . . . . . . . .
# Status     . . . . . . . . . . . . . . . . . .
# Estimator  . . . . . . . . . . . . . . . . . .
#
#
#
# Initiated                         11:10:01
# Status                     Fitting 3 Folds
# Estimator  Light Gradient Boosting Machine
# <pandas.io.formats.style.Styler object at 0x7f8de2802340>
#                                                 \
#
# Initiated  . . . . . . . . . . . . . . . . . .
# Status     . . . . . . . . . . . . . . . . . .
# Estimator  . . . . . . . . . . . . . . . . . .
#
#
#
# Initiated                         11:10:01
# Status              Compiling Final Models
# Estimator  Light Gradient Boosting Machine
#                                                 \
#
# Initiated  . . . . . . . . . . . . . . . . . .
# Status     . . . . . . . . . . . . . . . . . .
# Estimator  . . . . . . . . . . . . . . . . . .
#
#
#
# Initiated                         11:10:01
# Status              Compiling Final Models
# Estimator  Light Gradient Boosting Machine
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                 11:10:01
# Status     . . . . . . . . . . . . . . . . . .   Compiling Final Models
# Estimator  . . . . . . . . . . . . . . . . . .  Random Forest Regressor
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                 11:10:01
# Status     . . . . . . . . . . . . . . . . . .   Compiling Final Models
# Estimator  . . . . . . . . . . . . . . . . . .  Random Forest Regressor
# #033[2K#015#033[2K#015<pandas.io.formats.style.Styler object at 0x7f8de2802340>
# 2021-07-30 11:10:55 Uploading - Uploading generated training model                                    Model         MAE  ...        MAPE  TT (Sec)
# rf                Random Forest Regressor      0.1228  ...      0.1976    1.2933
# lightgbm  Light Gradient Boosting Machine      0.1384  ...      0.2171    0.2567
# et                  Extra Trees Regressor      0.1273  ...      0.2049    0.8067
# gbr           Gradient Boosting Regressor      0.1674  ...      0.2541    3.3633
# knn                 K Neighbors Regressor      0.1633  ...      0.2646    0.7567
# dt                Decision Tree Regressor      0.1348  ...      0.2454    0.4933
# ridge                    Ridge Regression      0.2217  ...      0.3222    0.3467
# br                         Bayesian Ridge      0.2217  ...      0.3219    0.3733
# omp           Orthogonal Matching Pursuit      0.2229  ...      0.3230    0.3500
# lr                      Linear Regression      0.2243  ...      0.3240    0.5033
# ada                    AdaBoost Regressor      0.2449  ...      0.3160    1.4300
# lasso                    Lasso Regression      0.3028  ...      0.3719    0.3500
# en                            Elastic Net      0.3028  ...      0.3719    0.3533
# llar         Lasso Least Angle Regression      0.3029  ...      0.3719    0.3500
# huber                     Huber Regressor      0.3762  ...      0.9992    0.3967
# par          Passive Aggressive Regressor    719.8585  ...   1629.9184    0.3867
# lar                Least Angle Regression  10406.5366  ...  22796.4650    0.3567
#
# [17 rows x 8 columns]
# Transformation Pipeline and Model Succesfully Saved
# model saved
# total time taken using multiprocessing is -  280.382030903
# training complete
# Sucess
#
# 2021-07-30 11:11:22 Completed - Training job completed
# Training seconds: 143
# Billable seconds: 143

# %% [markdown]
# ### 4. Sample Data

# %%
# maintaine this directory structure
import os
TRANSFORM_WORKDIR = "data/transform"
sample_data = pd.read_csv(TRANSFORM_WORKDIR + "/sample_input.csv",index_col=0)
sample_data.head(10)
# Out:
#      LoanDuration  MonthlyPayment  Amount  Gender  IncomeTotal  UseOfLoan  \
# Age
# 53             60           62.05    2125       1          354          2
# 50             60           84.75    3000       1          900          3
# 42             60           63.53    1500       0          863          2
# 34             48          101.19    1090       1          697          7
# 31             60          243.19     775       1          970          7
# 22             60          155.89    3190       1          430          7
# 23             60           93.22    2500       1          554          6
# 45             60          393.93     465       0         2500          2
# 28             60          160.68    3500       0          418          3
# 28             60          153.53    3780       1          595          7
#
#      Education   WorkExperience  HomeOwnershipType  OccupationArea  \
# Age
# 53           4      15To25Years                  1               1
# 50           5  MoreThan25Years                  1               7
# 42           2       5To10Years                  2               1
# 34           4       5To10Years                  3               1
# 31           4      10To15Years                  4               7
# 22           3   LessThan2Years                  2               3
# 23           4        2To5Years                  7               3
# 45           5      15To25Years                  1              17
# 28           2       5To10Years                  2              19
# 28           2      10To15Years                  2               1
#
#      LossGivenDefault
# Age
# 53               0.58
# 50               0.65
# 42               0.90
# 34               0.75
# 31               0.90
# 22               0.58
# 23               0.65
# 45               0.90
# 28               0.65
# 28               0.65

# %% [markdown]
# ### 5. Perform batch inference

# %% [markdown]
# In this section, you will perform batch inference using multiple input payloads together. If you are not familiar with batch transform, and want to learn more, see these links:
# 1. [How it works](https://docs.aws.amazon.com/sagemaker/latest/dg/ex1-batch-transform.html)
# 2. [How to run a batch transform job](https://docs.aws.amazon.com/sagemaker/latest/dg/how-it-works-batch.html)

# %%
TRANSFORM_WORKDIR = "data/transform"
transform_input = sagemaker_session.upload_data(TRANSFORM_WORKDIR, key_prefix=batch_inference_input_prefix) + "/sample_input.csv"
print("Transform input uploaded to " + transform_input)
# Out:
# Transform input uploaded to s3://sagemaker-us-east-2-786796469737/Peer_to_Peer_Default_Loss_Prediction/batch-inference-input-data/sample_input.csv

# %%
transformer = algo.transformer(1, 'ml.m5.12xlarge')
transformer.transform(transform_input, content_type='text/csv')
transformer.wait()

print("Batch Transform output saved to " + transformer.output_path)
# Out:
# ..........
# ............................RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# Starting the inference server with 48 workers.
# [2021-07-30 11:18:54 +0000] [65] [INFO] Starting gunicorn 20.1.0
# [2021-07-30 11:18:54 +0000] [65] [INFO] Listening at: unix:/tmp/gunicorn.sock (65)
# [2021-07-30 11:18:54 +0000] [65] [INFO] Using worker: gevent
# [2021-07-30 11:18:54 +0000] [68] [INFO] Booting worker with pid: 68
# [2021-07-30 11:18:54 +0000] [69] [INFO] Booting worker with pid: 69
# [2021-07-30 11:18:54 +0000] [117] [INFO] Booting worker with pid: 117
# [2021-07-30 11:18:54 +0000] [118] [INFO] Booting worker with pid: 118
# [2021-07-30 11:18:54 +0000] [166] [INFO] Booting worker with pid: 166
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# [2021-07-30 11:18:55 +0000] [175] [INFO] Booting worker with pid: 175
# [2021-07-30 11:18:55 +0000] [223] [INFO] Booting worker with pid: 223
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# [2021-07-30 11:18:55 +0000] [326] [INFO] Booting worker with pid: 326
# [2021-07-30 11:18:55 +0000] [327] [INFO] Booting worker with pid: 327
# [2021-07-30 11:18:55 +0000] [375] [INFO] Booting worker with pid: 375
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# [2021-07-30 11:18:55 +0000] [431] [INFO] Booting worker with pid: 431
# [2021-07-30 11:18:55 +0000] [432] [INFO] Booting worker with pid: 432
# [2021-07-30 11:18:55 +0000] [434] [INFO] Booting worker with pid: 434
# [2021-07-30 11:18:55 +0000] [433] [INFO] Booting worker with pid: 433
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# Starting the inference server with 48 workers.
# [2021-07-30 11:18:54 +0000] [65] [INFO] Starting gunicorn 20.1.0
# [2021-07-30 11:18:54 +0000] [65] [INFO] Listening at: unix:/tmp/gunicorn.sock (65)
# [2021-07-30 11:18:54 +0000] [65] [INFO] Using worker: gevent
# [2021-07-30 11:18:54 +0000] [68] [INFO] Booting worker with pid: 68
# [2021-07-30 11:18:54 +0000] [69] [INFO] Booting worker with pid: 69
# [2021-07-30 11:18:54 +0000] [117] [INFO] Booting worker with pid: 117
# [2021-07-30 11:18:54 +0000] [118] [INFO] Booting worker with pid: 118
# [2021-07-30 11:18:54 +0000] [166] [INFO] Booting worker with pid: 166
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# [2021-07-30 11:18:55 +0000] [175] [INFO] Booting worker with pid: 175
# [2021-07-30 11:18:55 +0000] [223] [INFO] Booting worker with pid: 223
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# [2021-07-30 11:18:55 +0000] [326] [INFO] Booting worker with pid: 326
# [2021-07-30 11:18:55 +0000] [327] [INFO] Booting worker with pid: 327
# [2021-07-30 11:18:55 +0000] [375] [INFO] Booting worker with pid: 375
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# [2021-07-30 11:18:55 +0000] [431] [INFO] Booting worker with pid: 431
# [2021-07-30 11:18:55 +0000] [432] [INFO] Booting worker with pid: 432
# [2021-07-30 11:18:55 +0000] [434] [INFO] Booting worker with pid: 434
# [2021-07-30 11:18:55 +0000] [433] [INFO] Booting worker with pid: 433
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# [2021-07-30 11:18:55 +0000] [544] [INFO] Booting worker with pid: 544
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# [2021-07-30 11:18:55 +0000] [627] [INFO] Booting worker with pid: 627
# [2021-07-30 11:18:55 +0000] [679] [INFO] Booting worker with pid: 679
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# [2021-07-30 11:18:55 +0000] [791] [INFO] Booting worker with pid: 791
# [2021-07-30 11:18:55 +0000] [886] [INFO] Booting worker with pid: 886
# [2021-07-30 11:18:55 +0000] [934] [INFO] Booting worker with pid: 934
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# [2021-07-30 11:18:55 +0000] [943] [INFO] Booting worker with pid: 943
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# [2021-07-30 11:18:55 +0000] [976] [INFO] Booting worker with pid: 976
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# [2021-07-30 11:18:56 +0000] [1134] [INFO] Booting worker with pid: 1134
# [2021-07-30 11:18:56 +0000] [1162] [INFO] Booting worker with pid: 1162
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# [2021-07-30 11:18:56 +0000] [1198] [INFO] Booting worker with pid: 1198
# [2021-07-30 11:18:56 +0000] [1239] [INFO] Booting worker with pid: 1239
# [2021-07-30 11:18:56 +0000] [1428] [INFO] Booting worker with pid: 1428
# [2021-07-30 11:18:56 +0000] [1429] [INFO] Booting worker with pid: 1429
# [2021-07-30 11:18:56 +0000] [1477] [INFO] Booting worker with pid: 1477
# [2021-07-30 11:18:56 +0000] [1576] [INFO] Booting worker with pid: 1576
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# [2021-07-30 11:18:55 +0000] [544] [INFO] Booting worker with pid: 544
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# [2021-07-30 11:18:55 +0000] [627] [INFO] Booting worker with pid: 627
# [2021-07-30 11:18:55 +0000] [679] [INFO] Booting worker with pid: 679
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# [2021-07-30 11:18:55 +0000] [791] [INFO] Booting worker with pid: 791
# [2021-07-30 11:18:55 +0000] [886] [INFO] Booting worker with pid: 886
# [2021-07-30 11:18:55 +0000] [934] [INFO] Booting worker with pid: 934
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# [2021-07-30 11:18:55 +0000] [943] [INFO] Booting worker with pid: 943
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# [2021-07-30 11:18:55 +0000] [976] [INFO] Booting worker with pid: 976
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# [2021-07-30 11:18:56 +0000] [1134] [INFO] Booting worker with pid: 1134
# [2021-07-30 11:18:56 +0000] [1162] [INFO] Booting worker with pid: 1162
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# [2021-07-30 11:18:56 +0000] [1198] [INFO] Booting worker with pid: 1198
# [2021-07-30 11:18:56 +0000] [1239] [INFO] Booting worker with pid: 1239
# [2021-07-30 11:18:56 +0000] [1428] [INFO] Booting worker with pid: 1428
# [2021-07-30 11:18:56 +0000] [1429] [INFO] Booting worker with pid: 1429
# [2021-07-30 11:18:56 +0000] [1477] [INFO] Booting worker with pid: 1477
# [2021-07-30 11:18:56 +0000] [1576] [INFO] Booting worker with pid: 1576
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# [2021-07-30 11:18:56 +0000] [1676] [INFO] Booting worker with pid: 1676
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# [2021-07-30 11:18:56 +0000] [1787] [INFO] Booting worker with pid: 1787
# [2021-07-30 11:18:56 +0000] [1788] [INFO] Booting worker with pid: 1788
# [2021-07-30 11:18:56 +0000] [1804] [INFO] Booting worker with pid: 1804
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# [2021-07-30 11:18:56 +0000] [1901] [INFO] Booting worker with pid: 1901
# [2021-07-30 11:18:56 +0000] [1996] [INFO] Booting worker with pid: 1996
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# [2021-07-30 11:18:56 +0000] [2052] [INFO] Booting worker with pid: 2052
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# [2021-07-30 11:18:56 +0000] [2108] [INFO] Booting worker with pid: 2108
# [2021-07-30 11:18:56 +0000] [2203] [INFO] Booting worker with pid: 2203
# [2021-07-30 11:18:56 +0000] [2251] [INFO] Booting worker with pid: 2251
# [2021-07-30 11:18:56 +0000] [2299] [INFO] Booting worker with pid: 2299
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# [2021-07-30 11:18:56 +0000] [2447] [INFO] Booting worker with pid: 2447
# [2021-07-30 11:18:56 +0000] [2451] [INFO] Booting worker with pid: 2451
# [2021-07-30 11:18:56 +0000] [2452] [INFO] Booting worker with pid: 2452
# [2021-07-30 11:18:57 +0000] [2547] [INFO] Booting worker with pid: 2547
# [2021-07-30 11:18:57 +0000] [2548] [INFO] Booting worker with pid: 2548
# [2021-07-30 11:18:57 +0000] [2557] [INFO] Booting worker with pid: 2557
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# [2021-07-30 11:18:57 +0000] [2574] [INFO] Booting worker with pid: 2574
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# [2021-07-30 11:18:56 +0000] [1676] [INFO] Booting worker with pid: 1676
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# [2021-07-30 11:18:56 +0000] [1787] [INFO] Booting worker with pid: 1787
# [2021-07-30 11:18:56 +0000] [1788] [INFO] Booting worker with pid: 1788
# [2021-07-30 11:18:56 +0000] [1804] [INFO] Booting worker with pid: 1804
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# [2021-07-30 11:18:56 +0000] [1901] [INFO] Booting worker with pid: 1901
# [2021-07-30 11:18:56 +0000] [1996] [INFO] Booting worker with pid: 1996
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# [2021-07-30 11:18:56 +0000] [2052] [INFO] Booting worker with pid: 2052
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# [2021-07-30 11:18:56 +0000] [2108] [INFO] Booting worker with pid: 2108
# [2021-07-30 11:18:56 +0000] [2203] [INFO] Booting worker with pid: 2203
# [2021-07-30 11:18:56 +0000] [2251] [INFO] Booting worker with pid: 2251
# [2021-07-30 11:18:56 +0000] [2299] [INFO] Booting worker with pid: 2299
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# [2021-07-30 11:18:56 +0000] [2447] [INFO] Booting worker with pid: 2447
# [2021-07-30 11:18:56 +0000] [2451] [INFO] Booting worker with pid: 2451
# [2021-07-30 11:18:56 +0000] [2452] [INFO] Booting worker with pid: 2452
# [2021-07-30 11:18:57 +0000] [2547] [INFO] Booting worker with pid: 2547
# [2021-07-30 11:18:57 +0000] [2548] [INFO] Booting worker with pid: 2548
# [2021-07-30 11:18:57 +0000] [2557] [INFO] Booting worker with pid: 2557
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# [2021-07-30 11:18:57 +0000] [2574] [INFO] Booting worker with pid: 2574
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# Transformation Pipeline and Model Successfully Loaded
# Transformation Pipeline and Model Successfully Loaded
# 169.254.255.130 - - [30/Jul/2021:11:19:02 +0000] "GET /ping HTTP/1.1" 200 1 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [30/Jul/2021:11:19:02 +0000] "GET /execution-parameters HTTP/1.1" 404 2 "-" "Go-http-client/1.1"
# Transformation Pipeline and Model Successfully Loaded
# Pipeline(steps=[('dtypes',
#                  DataTypes_Auto_infer(display_types=False,
#                                       ml_usecase='regression',
#                                       target='LossGivenDefault')),
#                 ('imputer',
#                  Simple_Imputer(categorical_strategy='most frequent',
#                                 fill_value_categorical=None,
#                                 fill_value_numerical=None,
#                                 numeric_strategy='mean',
#                                 target_variable=None)),
#                 ('new_levels1',
#                  New_Catagorical_Levels_in_TestData(replacement_strate...
#                  Fix_multicollinearity(correlation_with_target_preference=None,
#                                        target_variable='LossGivenDefault',
#                                        threshold=0.9)),
#                 ('dfs',
#                  DFS_Classic(interactions=['multiply', 'divide'],
#                              ml_usecase='regression', n_jobs=-1,
#                              random_state=123, subclass='binary',
#                              target='LossGivenDefault',
#                              top_features_to_pick_percentage=None)),
#                 ('pca', 'passthrough'),
#                 ['trained_model',
#                  RandomForestRegressor(n_jobs=-1, random_state=123)]])
# 169.254.255.130 - - [30/Jul/2021:11:19:02 +0000] "POST /invocations HTTP/1.1" 200 6908 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [30/Jul/2021:11:19:02 +0000] "GET /ping HTTP/1.1" 200 1 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [30/Jul/2021:11:19:02 +0000] "GET /execution-parameters HTTP/1.1" 404 2 "-" "Go-http-client/1.1"
# Transformation Pipeline and Model Successfully Loaded
# Pipeline(steps=[('dtypes',
#                  DataTypes_Auto_infer(display_types=False,
#                                       ml_usecase='regression',
#                                       target='LossGivenDefault')),
#                 ('imputer',
#                  Simple_Imputer(categorical_strategy='most frequent',
#                                 fill_value_categorical=None,
#                                 fill_value_numerical=None,
#                                 numeric_strategy='mean',
#                                 target_variable=None)),
#                 ('new_levels1',
#                  New_Catagorical_Levels_in_TestData(replacement_strate...
#                  Fix_multicollinearity(correlation_with_target_preference=None,
#                                        target_variable='LossGivenDefault',
#                                        threshold=0.9)),
#                 ('dfs',
#                  DFS_Classic(interactions=['multiply', 'divide'],
#                              ml_usecase='regression', n_jobs=-1,
#                              random_state=123, subclass='binary',
#                              target='LossGivenDefault',
#                              top_features_to_pick_percentage=None)),
#                 ('pca', 'passthrough'),
#                 ['trained_model',
#                  RandomForestRegressor(n_jobs=-1, random_state=123)]])
# 169.254.255.130 - - [30/Jul/2021:11:19:02 +0000] "POST /invocations HTTP/1.1" 200 6908 "-" "Go-http-client/1.1"
# 2021-07-30T11:19:02.393:[sagemaker logs]: MaxConcurrentTransforms=1, MaxPayloadInMB=6, BatchStrategy=MULTI_RECORD
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# Starting the inference server with 48 workers.
# [2021-07-30 11:18:54 +0000] [65] [INFO] Starting gunicorn 20.1.0
# [2021-07-30 11:18:54 +0000] [65] [INFO] Listening at: unix:/tmp/gunicorn.sock (65)
# [2021-07-30 11:18:54 +0000] [65] [INFO] Using worker: gevent
# [2021-07-30 11:18:54 +0000] [68] [INFO] Booting worker with pid: 68
# [2021-07-30 11:18:54 +0000] [69] [INFO] Booting worker with pid: 69
# [2021-07-30 11:18:54 +0000] [117] [INFO] Booting worker with pid: 117
# [2021-07-30 11:18:54 +0000] [118] [INFO] Booting worker with pid: 118
# [2021-07-30 11:18:54 +0000] [166] [INFO] Booting worker with pid: 166
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# [2021-07-30 11:18:55 +0000] [175] [INFO] Booting worker with pid: 175
# [2021-07-30 11:18:55 +0000] [223] [INFO] Booting worker with pid: 223
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# [2021-07-30 11:18:55 +0000] [326] [INFO] Booting worker with pid: 326
# [2021-07-30 11:18:55 +0000] [327] [INFO] Booting worker with pid: 327
# [2021-07-30 11:18:55 +0000] [375] [INFO] Booting worker with pid: 375
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# [2021-07-30 11:18:55 +0000] [431] [INFO] Booting worker with pid: 431
# [2021-07-30 11:18:55 +0000] [432] [INFO] Booting worker with pid: 432
# [2021-07-30 11:18:55 +0000] [434] [INFO] Booting worker with pid: 434
# [2021-07-30 11:18:55 +0000] [433] [INFO] Booting worker with pid: 433
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# Starting the inference server with 48 workers.
# [2021-07-30 11:18:54 +0000] [65] [INFO] Starting gunicorn 20.1.0
# [2021-07-30 11:18:54 +0000] [65] [INFO] Listening at: unix:/tmp/gunicorn.sock (65)
# [2021-07-30 11:18:54 +0000] [65] [INFO] Using worker: gevent
# [2021-07-30 11:18:54 +0000] [68] [INFO] Booting worker with pid: 68
# [2021-07-30 11:18:54 +0000] [69] [INFO] Booting worker with pid: 69
# [2021-07-30 11:18:54 +0000] [117] [INFO] Booting worker with pid: 117
# [2021-07-30 11:18:54 +0000] [118] [INFO] Booting worker with pid: 118
# [2021-07-30 11:18:54 +0000] [166] [INFO] Booting worker with pid: 166
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# [2021-07-30 11:18:55 +0000] [175] [INFO] Booting worker with pid: 175
# [2021-07-30 11:18:55 +0000] [223] [INFO] Booting worker with pid: 223
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# [2021-07-30 11:18:55 +0000] [326] [INFO] Booting worker with pid: 326
# [2021-07-30 11:18:55 +0000] [327] [INFO] Booting worker with pid: 327
# [2021-07-30 11:18:55 +0000] [375] [INFO] Booting worker with pid: 375
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# [2021-07-30 11:18:55 +0000] [431] [INFO] Booting worker with pid: 431
# [2021-07-30 11:18:55 +0000] [432] [INFO] Booting worker with pid: 432
# [2021-07-30 11:18:55 +0000] [434] [INFO] Booting worker with pid: 434
# [2021-07-30 11:18:55 +0000] [433] [INFO] Booting worker with pid: 433
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# [2021-07-30 11:18:55 +0000] [544] [INFO] Booting worker with pid: 544
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# [2021-07-30 11:18:55 +0000] [627] [INFO] Booting worker with pid: 627
# [2021-07-30 11:18:55 +0000] [679] [INFO] Booting worker with pid: 679
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# [2021-07-30 11:18:55 +0000] [791] [INFO] Booting worker with pid: 791
# [2021-07-30 11:18:55 +0000] [886] [INFO] Booting worker with pid: 886
# [2021-07-30 11:18:55 +0000] [934] [INFO] Booting worker with pid: 934
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# [2021-07-30 11:18:55 +0000] [943] [INFO] Booting worker with pid: 943
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# [2021-07-30 11:18:55 +0000] [976] [INFO] Booting worker with pid: 976
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# [2021-07-30 11:18:56 +0000] [1134] [INFO] Booting worker with pid: 1134
# [2021-07-30 11:18:56 +0000] [1162] [INFO] Booting worker with pid: 1162
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# [2021-07-30 11:18:56 +0000] [1198] [INFO] Booting worker with pid: 1198
# [2021-07-30 11:18:56 +0000] [1239] [INFO] Booting worker with pid: 1239
# [2021-07-30 11:18:56 +0000] [1428] [INFO] Booting worker with pid: 1428
# [2021-07-30 11:18:56 +0000] [1429] [INFO] Booting worker with pid: 1429
# [2021-07-30 11:18:56 +0000] [1477] [INFO] Booting worker with pid: 1477
# [2021-07-30 11:18:56 +0000] [1576] [INFO] Booting worker with pid: 1576
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# [2021-07-30 11:18:55 +0000] [544] [INFO] Booting worker with pid: 544
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# [2021-07-30 11:18:55 +0000] [627] [INFO] Booting worker with pid: 627
# [2021-07-30 11:18:55 +0000] [679] [INFO] Booting worker with pid: 679
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# [2021-07-30 11:18:55 +0000] [791] [INFO] Booting worker with pid: 791
# [2021-07-30 11:18:55 +0000] [886] [INFO] Booting worker with pid: 886
# [2021-07-30 11:18:55 +0000] [934] [INFO] Booting worker with pid: 934
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# [2021-07-30 11:18:55 +0000] [943] [INFO] Booting worker with pid: 943
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# [2021-07-30 11:18:55 +0000] [976] [INFO] Booting worker with pid: 976
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# [2021-07-30 11:18:56 +0000] [1134] [INFO] Booting worker with pid: 1134
# [2021-07-30 11:18:56 +0000] [1162] [INFO] Booting worker with pid: 1162
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# [2021-07-30 11:18:56 +0000] [1198] [INFO] Booting worker with pid: 1198
# [2021-07-30 11:18:56 +0000] [1239] [INFO] Booting worker with pid: 1239
# [2021-07-30 11:18:56 +0000] [1428] [INFO] Booting worker with pid: 1428
# [2021-07-30 11:18:56 +0000] [1429] [INFO] Booting worker with pid: 1429
# [2021-07-30 11:18:56 +0000] [1477] [INFO] Booting worker with pid: 1477
# [2021-07-30 11:18:56 +0000] [1576] [INFO] Booting worker with pid: 1576
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# [2021-07-30 11:18:56 +0000] [1676] [INFO] Booting worker with pid: 1676
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# [2021-07-30 11:18:56 +0000] [1787] [INFO] Booting worker with pid: 1787
# [2021-07-30 11:18:56 +0000] [1788] [INFO] Booting worker with pid: 1788
# [2021-07-30 11:18:56 +0000] [1804] [INFO] Booting worker with pid: 1804
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# [2021-07-30 11:18:56 +0000] [1901] [INFO] Booting worker with pid: 1901
# [2021-07-30 11:18:56 +0000] [1996] [INFO] Booting worker with pid: 1996
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# [2021-07-30 11:18:56 +0000] [2052] [INFO] Booting worker with pid: 2052
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# [2021-07-30 11:18:56 +0000] [2108] [INFO] Booting worker with pid: 2108
# [2021-07-30 11:18:56 +0000] [2203] [INFO] Booting worker with pid: 2203
# [2021-07-30 11:18:56 +0000] [2251] [INFO] Booting worker with pid: 2251
# [2021-07-30 11:18:56 +0000] [2299] [INFO] Booting worker with pid: 2299
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# [2021-07-30 11:18:56 +0000] [2447] [INFO] Booting worker with pid: 2447
# [2021-07-30 11:18:56 +0000] [2451] [INFO] Booting worker with pid: 2451
# [2021-07-30 11:18:56 +0000] [2452] [INFO] Booting worker with pid: 2452
# [2021-07-30 11:18:57 +0000] [2547] [INFO] Booting worker with pid: 2547
# [2021-07-30 11:18:57 +0000] [2548] [INFO] Booting worker with pid: 2548
# [2021-07-30 11:18:57 +0000] [2557] [INFO] Booting worker with pid: 2557
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# [2021-07-30 11:18:57 +0000] [2574] [INFO] Booting worker with pid: 2574
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# [2021-07-30 11:18:56 +0000] [1676] [INFO] Booting worker with pid: 1676
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# [2021-07-30 11:18:56 +0000] [1787] [INFO] Booting worker with pid: 1787
# [2021-07-30 11:18:56 +0000] [1788] [INFO] Booting worker with pid: 1788
# [2021-07-30 11:18:56 +0000] [1804] [INFO] Booting worker with pid: 1804
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# [2021-07-30 11:18:56 +0000] [1901] [INFO] Booting worker with pid: 1901
# [2021-07-30 11:18:56 +0000] [1996] [INFO] Booting worker with pid: 1996
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# [2021-07-30 11:18:56 +0000] [2052] [INFO] Booting worker with pid: 2052
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# [2021-07-30 11:18:56 +0000] [2108] [INFO] Booting worker with pid: 2108
# [2021-07-30 11:18:56 +0000] [2203] [INFO] Booting worker with pid: 2203
# [2021-07-30 11:18:56 +0000] [2251] [INFO] Booting worker with pid: 2251
# [2021-07-30 11:18:56 +0000] [2299] [INFO] Booting worker with pid: 2299
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# [2021-07-30 11:18:56 +0000] [2447] [INFO] Booting worker with pid: 2447
# [2021-07-30 11:18:56 +0000] [2451] [INFO] Booting worker with pid: 2451
# [2021-07-30 11:18:56 +0000] [2452] [INFO] Booting worker with pid: 2452
# [2021-07-30 11:18:57 +0000] [2547] [INFO] Booting worker with pid: 2547
# [2021-07-30 11:18:57 +0000] [2548] [INFO] Booting worker with pid: 2548
# [2021-07-30 11:18:57 +0000] [2557] [INFO] Booting worker with pid: 2557
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# [2021-07-30 11:18:57 +0000] [2574] [INFO] Booting worker with pid: 2574
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# Transformation Pipeline and Model Successfully Loaded
# Transformation Pipeline and Model Successfully Loaded
# 169.254.255.130 - - [30/Jul/2021:11:19:02 +0000] "GET /ping HTTP/1.1" 200 1 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [30/Jul/2021:11:19:02 +0000] "GET /execution-parameters HTTP/1.1" 404 2 "-" "Go-http-client/1.1"
# Transformation Pipeline and Model Successfully Loaded
# Pipeline(steps=[('dtypes',
#                  DataTypes_Auto_infer(display_types=False,
#                                       ml_usecase='regression',
#                                       target='LossGivenDefault')),
#                 ('imputer',
#                  Simple_Imputer(categorical_strategy='most frequent',
#                                 fill_value_categorical=None,
#                                 fill_value_numerical=None,
#                                 numeric_strategy='mean',
#                                 target_variable=None)),
#                 ('new_levels1',
#                  New_Catagorical_Levels_in_TestData(replacement_strate...
#                  Fix_multicollinearity(correlation_with_target_preference=None,
#                                        target_variable='LossGivenDefault',
#                                        threshold=0.9)),
#                 ('dfs',
#                  DFS_Classic(interactions=['multiply', 'divide'],
#                              ml_usecase='regression', n_jobs=-1,
#                              random_state=123, subclass='binary',
#                              target='LossGivenDefault',
#                              top_features_to_pick_percentage=None)),
#                 ('pca', 'passthrough'),
#                 ['trained_model',
#                  RandomForestRegressor(n_jobs=-1, random_state=123)]])
# 169.254.255.130 - - [30/Jul/2021:11:19:02 +0000] "POST /invocations HTTP/1.1" 200 6908 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [30/Jul/2021:11:19:02 +0000] "GET /ping HTTP/1.1" 200 1 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [30/Jul/2021:11:19:02 +0000] "GET /execution-parameters HTTP/1.1" 404 2 "-" "Go-http-client/1.1"
# Transformation Pipeline and Model Successfully Loaded
# Pipeline(steps=[('dtypes',
#                  DataTypes_Auto_infer(display_types=False,
#                                       ml_usecase='regression',
#                                       target='LossGivenDefault')),
#                 ('imputer',
#                  Simple_Imputer(categorical_strategy='most frequent',
#                                 fill_value_categorical=None,
#                                 fill_value_numerical=None,
#                                 numeric_strategy='mean',
#                                 target_variable=None)),
#                 ('new_levels1',
#                  New_Catagorical_Levels_in_TestData(replacement_strate...
#                  Fix_multicollinearity(correlation_with_target_preference=None,
#                                        target_variable='LossGivenDefault',
#                                        threshold=0.9)),
#                 ('dfs',
#                  DFS_Classic(interactions=['multiply', 'divide'],
#                              ml_usecase='regression', n_jobs=-1,
#                              random_state=123, subclass='binary',
#                              target='LossGivenDefault',
#                              top_features_to_pick_percentage=None)),
#                 ('pca', 'passthrough'),
#                 ['trained_model',
#                  RandomForestRegressor(n_jobs=-1, random_state=123)]])
# 169.254.255.130 - - [30/Jul/2021:11:19:02 +0000] "POST /invocations HTTP/1.1" 200 6908 "-" "Go-http-client/1.1"
# 2021-07-30T11:19:02.393:[sagemaker logs]: MaxConcurrentTransforms=1, MaxPayloadInMB=6, BatchStrategy=MULTI_RECORD
# Batch Transform output saved to s3://sagemaker-us-east-2-786796469737/Peer-to-Peer-Default-Loss-Prediction-2021-07-30-11-14-31-971

# %% [markdown]
# #### Inspect the Batch Transform Output in S3

# %%
from urllib.parse import urlparse

parsed_url = urlparse(transformer.output_path)
bucket_name = parsed_url.netloc
file_key = '{}/{}.out'.format(parsed_url.path[1:], 'sample_input.csv')

s3_client = sagemaker_session.boto_session.client('s3')

response = s3_client.get_object(Bucket = sagemaker_session.default_bucket(), Key = file_key)
response_bytes = response['Body'].read().decode('utf-8')

# %%
bucketFolder = transformer.output_path.rsplit('/')[3]

# %%
import boto3
s3_conn = boto3.client("s3")
bucket_name=sagemaker_session.default_bucket()
with open('sample_output.csv', 'wb') as f:
    s3_conn.download_fileobj(bucket_name, bucketFolder+'/' + 'sample_input.csv' +'.out', f)
    print("Output file loaded from bucket")
# Out:
# Output file loaded from bucket

# %% [markdown]
# ### output

# %%
#OUTPUT_WORKDIR = "data/output"

import pandas as pd

out_csv = pd.read_csv("sample_output.csv",index_col=0)
out_csv.head(10)
# Out:
#      LoanDuration  MonthlyPayment  Amount  Gender  IncomeTotal  UseOfLoan  \
# Age
# 53             60           62.05    2125       1          354          2
# 50             60           84.75    3000       1          900          3
# 42             60           63.53    1500       0          863          2
# 34             48          101.19    1090       1          697          7
# 31             60          243.19     775       1          970          7
# 22             60          155.89    3190       1          430          7
# 23             60           93.22    2500       1          554          6
# 45             60          393.93     465       0         2500          2
# 28             60          160.68    3500       0          418          3
# 28             60          153.53    3780       1          595          7
#
#      Education   WorkExperience  HomeOwnershipType  OccupationArea  \
# Age
# 53           4      15To25Years                  1               1
# 50           5  MoreThan25Years                  1               7
# 42           2       5To10Years                  2               1
# 34           4       5To10Years                  3               1
# 31           4      10To15Years                  4               7
# 22           3   LessThan2Years                  2               3
# 23           4        2To5Years                  7               3
# 45           5      15To25Years                  1              17
# 28           2       5To10Years                  2              19
# 28           2      10To15Years                  2               1
#
#      LossGivenDefault     Label
# Age
# 53               0.58  0.586300
# 50               0.65  0.660300
# 42               0.90  0.782123
# 34               0.75  0.754600
# 31               0.90  0.858900
# 22               0.58  0.612500
# 23               0.65  0.651100
# 45               0.90  0.851200
# 28               0.65  0.635500
# 28               0.65  0.618900

# %% [markdown]
# ### 6. Create an endpoint and perform real-time inference

# %% [markdown]
# If you want to understand how real-time inference with Amazon SageMaker works, see [Documentation](https://docs.aws.amazon.com/sagemaker/latest/dg/how-it-works-hosting.html).

# %%
model_name='Peer-to-Peer-Default-Loss-Prediction'

content_type='text/csv'

real_time_inference_instance_type='ml.m5.12xlarge'
batch_transform_inference_instance_type='ml.m5.12xlarge'

# %% [markdown]
# ##### Algorithm ARN

# %%
algorithm_arn ='' # put your ARN here

# %% [markdown]
# #### A. Create an endpoint

# %%
def predict_wrapper(endpoint, session):
    return sage.RealTimePredictor(endpoint, session,content_type)

#create a deployable model from the model package.
model = ModelPackage(role=role,
                    model_package_arn=algorithm_arn,
                    sagemaker_session=sagemaker_session,
                    predictor_cls=predict_wrapper)

#Deploy the model
predictor = algo.deploy(1, 'ml.m5.12xlarge',endpoint_name=model_name)
# Out:
# ..........
# -----------!

# %% [markdown]
# Once endpoint has been created, you would be able to perform real-time inference.

# %% [markdown]
# #### B. Create input payload

# %%
import pandas as pd
file_name = 'data/transform/sample_input.csv'
data_frame = pd.read_csv(file_name)

# %% [markdown]
# #### C. Perform real-time inference

# %%
# !aws sagemaker-runtime invoke-endpoint \
    --endpoint-name 'Peer-to-Peer-Default-Loss-Prediction' \
    --body fileb://$file_name \
    --content-type 'text/csv' \
    --region us-east-2 \
    sample_output.csv
# Out:
# {
#     "ContentType": "text/csv; charset=utf-8",
#     "InvokedProductionVariant": "AllTraffic"
# }

# %% [markdown]
# #### D. Visualize output

# %%
out_csv = pd.read_csv("sample_output.csv",index_col=0)
out_csv.head(10)
# Out:
#      LoanDuration  MonthlyPayment  Amount  Gender  IncomeTotal  UseOfLoan  \
# Age
# 53             60           62.05    2125       1          354          2
# 50             60           84.75    3000       1          900          3
# 42             60           63.53    1500       0          863          2
# 34             48          101.19    1090       1          697          7
# 31             60          243.19     775       1          970          7
# 22             60          155.89    3190       1          430          7
# 23             60           93.22    2500       1          554          6
# 45             60          393.93     465       0         2500          2
# 28             60          160.68    3500       0          418          3
# 28             60          153.53    3780       1          595          7
#
#      Education   WorkExperience  HomeOwnershipType  OccupationArea  \
# Age
# 53           4      15To25Years                  1               1
# 50           5  MoreThan25Years                  1               7
# 42           2       5To10Years                  2               1
# 34           4       5To10Years                  3               1
# 31           4      10To15Years                  4               7
# 22           3   LessThan2Years                  2               3
# 23           4        2To5Years                  7               3
# 45           5      15To25Years                  1              17
# 28           2       5To10Years                  2              19
# 28           2      10To15Years                  2               1
#
#      LossGivenDefault     Label
# Age
# 53               0.58  0.586300
# 50               0.65  0.660300
# 42               0.90  0.782123
# 34               0.75  0.754600
# 31               0.90  0.858900
# 22               0.58  0.612500
# 23               0.65  0.651100
# 45               0.90  0.851200
# 28               0.65  0.635500
# 28               0.65  0.618900

# %% [markdown]
# ### 7. Clean-up

# %% [markdown]
# #### A. Delete the model

# %%
predictor.delete_endpoint()

# %% [markdown]
# #### B. Unsubscribe to the listing (optional)

# %% [markdown]
# If you would like to unsubscribe to the model package, follow these steps. Before you cancel the subscription, ensure that you do not have any [deployable model](https://console.aws.amazon.com/sagemaker/home#/models) created from the model package or using the algorithm. Note - You can find this information by looking at the container name associated with the model.
#
# **Steps to unsubscribe to product from AWS Marketplace**:
# 1. Navigate to __Machine Learning__ tab on [__Your Software subscriptions page__](https://aws.amazon.com/marketplace/ai/library?productType=ml&ref_=mlmp_gitdemo_indust)
# 2. Locate the listing that you want to cancel the subscription for, and then choose __Cancel Subscription__  to cancel the subscription.
